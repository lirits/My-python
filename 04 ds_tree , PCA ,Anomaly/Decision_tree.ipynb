# %% [markdown]
# # Decision tree

# %% [markdown]
# ## job
# 1. establish a decision_model to train the irirs data
# 2. accuracy and visualize the predict results
# 3. change the min_samples_leaf and get a new result

# %%
# load the data
import pandas as pd
import numpy as np
data = pd.read_csv('iris_data.csv')
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target  label
# 0           5.1          3.5           1.4          0.2  Iris-setosa      0
# 1           4.9          3.0           1.4          0.2  Iris-setosa      0
# 2           4.7          3.2           1.3          0.2  Iris-setosa      0
# 3           4.6          3.1           1.5          0.2  Iris-setosa      0
# 4           5.0          3.6           1.4          0.2  Iris-setosa      0

# %%
#define the X and y
X = data.drop(['target','label'],axis=1)
y = data.loc[:,'label']
print(X.shape,y.shape)
# Out:
# (150, 4) (150,)

# %%
#establish the decision tree 
from sklearn import tree
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf =5)
dc_tree.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=5)

# %%
#evaluate the model
y_predict = dc_tree.predict(X)
from sklearn.metrics import accuracy_score
accury = accuracy_score(y,y_predict)
print(accury)
# Out:
# 0.9733333333333334

# %%
#visualize the tree
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(10,10))
tree.plot_tree(dc_tree,filled='True',feature_names=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'],class_names=['setosa','versicolor','virginica'])
# Out:
# [Text(248.0, 489.24, 'PetalLength <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(186.0, 380.52000000000004, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(310.0, 380.52000000000004, 'PetalWidth <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(186.0, 271.8, 'PetalLength <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(124.0, 163.08000000000004, 'SepalLength <= 5.15\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(62.0, 54.360000000000014, 'entropy = 0.722\nsamples = 5\nvalue = [0, 4, 1]\nclass = versicolor'),
#  Text(186.0, 54.360000000000014, 'entropy = 0.0\nsamples = 43\nvalue = [0, 43, 0]\nclass = versicolor'),
#  Text(248.0, 163.08000000000004, 'entropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(434.0, 271.8, 'PetalLength <= 4.95\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica'),
#  Text(372.0, 163.08000000000004, 'entropy = 0.65\nsamples = 6\nvalue = [0, 1, 5]\nclass = virginica'),
#  Text(496.0, 163.08000000000004, 'entropy = 0.0\nsamples = 40\nvalue = [0, 0, 40]\nclass = virginica')]

# %%
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf=10)
dc_tree.fit(X,y)
fig = plt.figure(figsize=(8,8))
tree.plot_tree(dc_tree,filled='True',feature_names=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'],class_names=['setosa','versicolor','virginica'])
# Out:
# [Text(167.39999999999998, 391.392, 'PetalWidth <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(111.6, 304.416, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(223.2, 304.416, 'PetalWidth <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(111.6, 217.44, 'PetalLength <= 4.45\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(55.8, 130.464, 'entropy = 0.0\nsamples = 29\nvalue = [0, 29, 0]\nclass = versicolor'),
#  Text(167.39999999999998, 130.464, 'SepalWidth <= 2.85\nentropy = 0.722\nsamples = 25\nvalue = [0, 20, 5]\nclass = versicolor'),
#  Text(111.6, 43.488, 'entropy = 0.946\nsamples = 11\nvalue = [0, 7, 4]\nclass = versicolor'),
#  Text(223.2, 43.488, 'entropy = 0.371\nsamples = 14\nvalue = [0, 13, 1]\nclass = versicolor'),
#  Text(334.79999999999995, 217.44, 'SepalLength <= 6.25\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica'),
#  Text(279.0, 130.464, 'entropy = 0.439\nsamples = 11\nvalue = [0, 1, 10]\nclass = virginica'),
#  Text(390.59999999999997, 130.464, 'entropy = 0.0\nsamples = 35\nvalue = [0, 0, 35]\nclass = virginica')]
